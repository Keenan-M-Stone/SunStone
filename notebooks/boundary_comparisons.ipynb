# %% [markdown]
# # Boundary per-face comparison notebook
#
# This notebook loads outputs for per-face boundary test runs (e.g., Meep) and compares them against experimental/reference data. Replace placeholder paths with actual run output files created by test runs.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Placeholder: load a field snapshot JSON written by backend (field_snapshot.json)
def load_field_snapshot(path):
    data = json.load(open(path))
    return np.array(data.get('data', [])), data.get('width'), data.get('height')

# Example usage:
# data, w, h = load_field_snapshot('runs/run_XXXX/outputs/fields/field_snapshot.json')
# img = data.reshape((h, w))
# plt.imshow(img, cmap='viridis'); plt.colorbar(); plt.show()
